# %% [markdown]
# # 경사 하강법(Gradient Descent)

# %% [markdown]
# # I. Machine( ) 정의
#
# * numpy Package

# %%
import numpy as np

# %% [markdown]
# * def Machine( )

# %%
def Machine(x, w, b):
    y_hat = (w * x) + b
    return y_hat

# %% [markdown]
# * x, w, b 객체 지정

# %%
x = np.array([1, 3, 5, 7, 9])
w = 2
b = 1

# %% [markdown]
# * Machine( ) 테스트

# %%
Machine(x, w, b)
# Out:
# array([ 3,  7, 11, 15, 19])

# %% [markdown]
# # II. Gradient( ) 정의
# * def Gradient( )

# %%
def Gradient(x, y, w, b):
    y_hat = Machine(x, w, b)

    dw = np.mean((y - y_hat) * (-2 * x))
    db = np.mean((y - y_hat) * (-2))

    GDs = np.array([dw, db])
    return GDs

# %% [markdown]
# * Gradient( ) 테스트

# %%
y = np.array([2, 4, 6, 8, 10])

GDs = Gradient(x, y, w, b)

# %%
print('dw is ', GDs[0])
print('db is ', GDs[1])
# Out:
# dw is  66.0
# db is  10.0

# %% [markdown]
# # III. Learning( ) 정의
# * def Learning( )

# %%
def Learning(x, y, w, b, step):
    GDs = Gradient(x, y, w, b)
    
    uw = w - step * GDs[0]
    ub = b - step * GDs[1]

    Updated = np.array([uw, ub])
    return Updated

# %% [markdown]
# * Learning( ) 테스트

# %%
step = 0.001

Parameters = Learning(x, y, w, b, step)

# %%
print('Updated_w is ', Parameters[0])
print('Updated_b is ', Parameters[1])
# Out:
# Updated_w is  1.9934
# Updated_b is  0.999

# %% [markdown]
# # IV. testData.csv에 적용

# %% [markdown]
# * pandas & matplotlib Packages

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# * Colab File Upload

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name = fn, length = len(uploaded[fn])))
# Out:
#      <input type="file" id="files-e53888a3-5561-4456-800b-4c5c25d4bfd9" name="files[]" multiple disabled />
#      <output id="result-e53888a3-5561-4456-800b-4c5c25d4bfd9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving testData.csv to testData.csv
# User uploaded file "testData.csv" with length 128698 bytes

# %% [markdown]
# * testData.csv Information

# %%
DATA = pd.read_csv('testData.csv')

# %%
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 2 columns):
# inputs     5000 non-null float64
# outputs    5000 non-null float64
# dtypes: float64(2)
# memory usage: 78.2 KB

# %%
DATA.head()
# Out:
#    inputs   outputs
# 0  0.2362  0.162367
# 1  0.9415  0.479356
# 2  0.3495  0.095733
# 3  0.3200 -0.111783
# 4  0.8335  0.386012

# %% [markdown]
# * testData.csv Visualization

# %%
plt.scatter(DATA.inputs, DATA.outputs, s = 0.5)
plt.show()

# %% [markdown]
# * 1500번 학습 실행

# %%
w = 2
b = 3
step = 0.05

# %%
for i in range(0, 1500):
    Parameters = Learning(DATA.inputs, DATA.outputs, w, b, step)
    w = Parameters[0]
    b = Parameters[1]
# 1500번 학습을 시킨다. 0 ~ 1499
# W,b 가 최적의 결과를 만들어낸다.

# %%
print('Learned_w is ', w)
print('Learned_b is ', b)
# Out:
# Learned_w is  0.5047279373038404
# Learned_b is  -0.1700505555495597

# %% [markdown]
# * 학습결과 회귀선 그리기

# %%
X = np.linspace(0, 1, 100)
Y = (w * X) + b

plt.scatter(DATA.inputs, DATA.outputs, s = 0.3)
plt.plot(X, Y, '-r', linewidth = 1.5)
# 그래프에다가 linear 선을 그린다.
plt.show()

# %% [markdown]
# # V. scipy Package
# * stats.linregress( )

# %%
from scipy import stats

w2, b2, r_value, p_value, std_err = \
    stats.linregress(DATA.inputs, DATA.outputs)

# %%
print("Learned_w2 is ", w2)
print("Learned_b2 is ", b2)
# Out:
# Learned_w2 is  0.5047279373038475
# Learned_b2 is  -0.1700505555495634

# %% [markdown]
# * Visualization

# %%
X = np.linspace(0, 1, 100)
Y = (w2 * X) + b2

plt.scatter(DATA.inputs, DATA.outputs, s = 0.3, color = 'gray')
plt.plot(X, Y, '-b', linewidth = 1.5)
plt.show()

# %% [markdown]
# # VI. Loss Visualization

# %% [markdown]
# * Gradient( )에 Loss 추가

# %%
def Gradient(x, y, w, b):
    y_hat = Machine(x, w, b)
    
    dw = np.mean((y - y_hat) * (-2 * x))
    db = np.mean((y - y_hat) * (-2))
    Loss = np.mean((y - y_hat)**2)

    GDs = np.array([dw, db, Loss])
    return GDs

# %% [markdown]
# * Learning( )에 Loss 추가

# %%
def Learning(x, y, w, b, step):
    GDs = Gradient(x, y, w, b)
    
    uw = w - step * GDs[0]
    ub = w - step * GDs[1]
    
    Loss = GDs[2]
    
    Updated = np.array([uw, ub, Loss])
    return Updated

# %% [markdown]
# * 1500번 학습 실행

# %%
w = 2
b = 3
step = 0.001
Loss = []

# %%
for i in range(0, 1500):
    Parameters = Learning(DATA.inputs, DATA.outputs, w, b, step)
    w = Parameters[0]
    b = Parameters[1]
    Loss.append(Parameters[2])

# %% [markdown]
# * Loss 감소 확인

# %%
Loss[0:10]
# Out:
# [15.595575679087696,
#  8.69089938668475,
#  8.66809956633206,
#  8.639564220815696,
#  8.611129682389118,
#  8.582789837087088,
#  8.554544374103527,
#  8.526392977931256,
#  8.498335334125741,
#  8.470371129295293]

# %%
plt.plot(Loss)
plt.show()

# %%
plt.plot(Loss[1:50], '.')
plt.show()

# %%
plt.plot(Loss[950:1000], '.')
plt.show()

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
